# %% [markdown]
# <a href="https://colab.research.google.com/github/bardiaHSZD/GameEngineDev/blob/main/Applications_of_AI_in_VFX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import dask.dataframe as dd

import gc

gc.enable()
plt.rcParams['figure.figsize'] = [15, 10]
import warnings
warnings.filterwarnings('ignore')

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
